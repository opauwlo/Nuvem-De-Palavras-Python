# %% [markdown]
# **Olá, este projeto é um gerador de wordcloud com base nos dados do twitter**
#
# ---
#
#
# > **Requisitos**
#
#
#
# 1.   Conta de desenvolvedor no twitter
#
#
#
#
# > Links De Apio
#
#
#
# *   [Pagina de Desenvolvedor Twitter](https://developer.twitter.com/en)
# *   [GitHub API Search_tweetsV2](https://github.com/twitterdev/search-tweets-python/tree/v2)
# *   [Pagina StopWords Português](https://gist.github.com/alopes/5358189)
#
# ---

# %%
# !pip install searchtweets-v2
# Out:
# Requirement already satisfied: searchtweets-v2 in /home/pauwlo/anaconda3/lib/python3.8/site-packages (1.0.7)
# Requirement already satisfied: requests in /home/pauwlo/anaconda3/lib/python3.8/site-packages (from searchtweets-v2) (2.24.0)
# Requirement already satisfied: python-dateutil in /home/pauwlo/.local/lib/python3.8/site-packages (from searchtweets-v2) (2.8.1)
# Requirement already satisfied: pyyaml in /home/pauwlo/anaconda3/lib/python3.8/site-packages (from searchtweets-v2) (5.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pauwlo/anaconda3/lib/python3.8/site-packages (from requests->searchtweets-v2) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/pauwlo/anaconda3/lib/python3.8/site-packages (from requests->searchtweets-v2) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /home/pauwlo/anaconda3/lib/python3.8/site-packages (from requests->searchtweets-v2) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/pauwlo/anaconda3/lib/python3.8/site-packages (from requests->searchtweets-v2) (3.0.4)
# Requirement already satisfied: six>=1.5 in /home/pauwlo/anaconda3/lib/python3.8/site-packages (from python-dateutil->searchtweets-v2) (1.15.0)

# %%
from searchtweets import ResultStream, gen_request_parameters, load_credentials
from searchtweets import collect_results
import os

# %%
stream_arg = load_credentials(filename="./config.yaml",
                 yaml_key="search_tweets_v2",
                 env_overwrite=False)

# %% [markdown]
# Nesta sessão você irá importar suas credenciais do twitter, obviamente as minhas não estão disponiveis aqui então você deve por as tuas. Você deve ter uma conta de desenvolvedor no twitter, mas não se preocupe basta preencher um simples formulario no sitee e aguradar a aprovação.

# %%
OUT_DIR = "./output_text"
LIMIT_PER_CALL = 100
LIMIT_MAX = 10000
termo_de_busca = "INEP"

# %% [markdown]
# **Aqui eu defino algumas variaveis.**
#
#
# ---
#
#
#
#
# > OUT_DIR
#
#
#
# **OUT_DIR** se refere ao diretoria de saida do arquivo que nosso script ira gerar.
#
# ---
#
#
# > LIMIT
#
#
#
# **LIMIT** se refere a quatidade de tweets por requisição, no meu e provavelmente no seu caso o twitter permite até **no máximo 100 tweets por requisição**.
#
# ---
#
#
#
# > LIMIT_MAX
#
#
# **LIMIT_MAX** se refere ao maximo de tweets que voce quer armazenar.
#
# ---
#
#
#
# > termo_de_busca
#
#
# **termo_de_busca** é a palavra chafe que você quer buscar.

# %%
for day in range(29,31):
  query = gen_request_parameters(f"{termo_de_busca} -is:retweet lang:pt", 
                               start_time = f"2021-03-{day}",
                               results_per_call=LIMIT_PER_CALL)
  
  tweets = collect_results(query,
                         max_tweets=LIMIT_MAX,
                         result_stream_args=stream_arg)
  
  print(f"{len(tweets)} resultados no dia {day}")
 
  with open(os.path.join(OUT_DIR, f"tweets_{termo_de_busca}.txt"), "a") as tweetsfile: 
    lines = [tweet['text'] for tweet in tweets if 'text' in tweet]
    tweetsfile.writelines(lines)
print("FIM")
# Out:
# 10102 resultados no dia 29
# 10102 resultados no dia 30
# FIM
